# %% [markdown]
# ## Quantifying Datasets
# Gauge the coverage for various sources for FULL TEXT papers.
#
# List of sources to check:
# 1. Unpaywall (includes pmid?)
# 2. BioArxiv
# 3. ChemArxiv

# %% [markdown]
# ## 1. Unpaywall

# %% [markdown]
# Will try using missing pmid's (use title query). This is in get_doi/refDict.p.

# %%
import urllib
import requests
import os
import math
import json
import pandas as pd

email = 'ivalexander13@berkeley.edu' # enter ur email pls

# %%
try:
    import cPickle as pickle
except ImportError:  # Python 3.x
    import pickle
    
with open('./get_doi/refDict.p', 'rb') as fp:
    refDict = pickle.load(fp)
    
# refDict is ready to use now.

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Pasted get_doi from get_doi.ipynb. This is the first way of querying. Modified to work with value insteaad of key

# %%
import lxml.etree as ET
import urllib
import re

def get_doi(metadata: dict):
    DOIerrors = {}
    data = metadata
#     for i in (["journal", "volume", "year","pages"]): # why is this here?
#     print(data)
    
    journal = " ".join(data["journal"].split())
    volume = "".join(data["volume"].split())
    year = "".join(data["year"].split())
    start_page = "".join(data["pages"].split()).split("-")[0]
    first_author_last_name = "".join(data["authors"].split(";")[0].split(",")[0].split())
    journal_title = journal.replace(" ", '%20')
    params = (first_author_last_name, journal_title, volume, start_page, year)
    url = "https://doi.crossref.org/openurl?pid=mrunali@berkeley.edu&aulast={}&title={}&volume={}&spage={}&date={}&noredirect=true".format(*params)

    data = urllib.request.urlopen(url).read()
#     print(data)
#     print(url)
    data = data.decode("utf-8")
    
#     print(li)

    if (data.find('unresolved') != -1):
        DOIerrors[key] = data
        return 
    else:
        try:
            doi = re.findall('(<doi.*>)(.*)<\/doi>', data)[0][1]
#             return "https://sci-hub.tw/{}".format(doi)
            return doi
        except Exception as e:
            DOIerrors[key] = data

# %% [markdown]
# Query by metadata by doi. Input is the value items in refDict.

# %%
# returns dict if found, else returns False.
def query_meta_doi(key: str, value: dict):
    doi = get_doi(value)
    url = f'https://api.unpaywall.org/v2/{doi}?email={email}'
    
    out_dict = requests.get(url).json()
    
    if 'error' in out_dict:
        return False
    else:
        return out_dict

# %%
query_meta_doi('659773', {
    'authors': 'Blacklock, T.J.; Sohar, P.; Butcher, J.W.; Lamanec, T.; Grabowski, E.J.J.',
    'title': 'An enantioselective synthesis of the topically-active carbonic anhydrase inhibitor MK-0507:5,6-dihydro-(s)-4-(ethylamino)-(s)-6-mehtyl-4H-thieno[2,3-beta]thiopyran-2-sulfonamide 7,7-dioxide hydrochloride',
    'journal': 'J. Org. Chem.',
    'volume': '58',
    'pages': '1672-1679',
    'year': '1993',
    'pubmedId': '0',
    'textmining': '0'
})
# Out:
# {'doi': '10.1021/jo00059a013',
#  'doi_url': 'https://doi.org/10.1021/jo00059a013',
#  'title': 'An enantioselective synthesis of the topically-active carbonic anhydrase inhibitor MK-0507: 5,6-dihydro-(S)-4-(ethylamino)-(S)-6-methyl-4H-thieno[2,3-b]thiopyran-2-sulfonamide 7,7-dioxide hydrochloride',
#  'genre': 'journal-article',
#  'is_paratext': False,
#  'published_date': '1993-03-01',
#  'year': 1993,
#  'journal_name': 'The Journal of Organic Chemistry',
#  'journal_issns': '0022-3263,1520-6904',
#  'journal_issn_l': '0022-3263',
#  'journal_is_oa': False,
#  'journal_is_in_doaj': False,
#  'publisher': 'American Chemical Society (ACS)',
#  'is_oa': False,
#  'oa_status': 'closed',
#  'has_repository_copy': False,
#  'best_oa_location': None,
#  'first_oa_location': None,
#  'oa_locations': [],
#  'updated': '2020-09-10T11:51:33.841618',
#  'data_standard': 2,
#  'z_authors': [{'family': 'Blacklock',
#    'given': 'Thomas J.',
#    'sequence': 'first'},
#   {'family': 'Sohar', 'given': 'Paul', 'sequence': 'additional'},
#   {'family': 'Butcher', 'given': 'John W.', 'sequence': 'additional'},
#   {'family': 'Lamanec', 'given': 'T.', 'sequence': 'additional'},
#   {'family': 'Grabowski', 'given': 'E. J. J.', 'sequence': 'additional'}]}

# %% [markdown]
# ## Main Query

# %% [markdown]
# For each item in refDict, check if it has been successfully called before, then try to get its doi (get_doi). If doi not found, use title query instead. If still not found, then mark it as fail.
#
# Adjustable things:
# - max_calls: int or False (if we want to query all)
# - delete the query_out.json file if you want to reset the data
# - Interrupt the loop by clicking "I" twice (or Kernel>Interrupt). The data will be saved, and stats shown.

# %%
# 1. check if json file is saved. Create or load a dict!!
json_file = './quantify_datasets/query_out.json'
if os.path.isfile(json_file):
    with open(json_file, 'r') as fp:
        query_out = json.load(fp)
        fp.close()
else:
    query_out = {}
    
# stats
max_calls = 90000 # max 100K per day (to be safe); or -1 if querying all.
calls = 0
queries = 0
fails = {}
are_oa = 0
successes_or_found = 0

# MAIN LOOP
try:
    # Looping through no-pmid papers (~12K)
    for key, value in refDict.items():
        key = str(math.floor(key))

        # stop before maxing out query
        if calls == max_calls or (queries == 99999):
            print("Query limit reached.")
            break
        else:
            calls += 1

        # 2. if not, then construct query
        if key not in query_out:  # there are 7 None's
            raw_title = value['title']
            if raw_title is not None:
                title = raw_title.strip()
            else:
                continue


            try:
                # First: DOI Query
                out_dict = query_meta_doi(key, value) # either dict or False
                queries += 1

                # if not found by doi, do title query. Errors if fails #fixme
                if not out_dict:
                    title_arg = title.replace(" ", '%20')
                    url = f'https://api.unpaywall.org/v2/search/?query={title_arg}&email={email}'
                    out_dict = requests.get(url).json()['results'][0]['response']
                    queries += 1


                # 4. append to DICT if successful
                query_out[key] = out_dict

                print(f"#### Call {calls} success")

                # Extra: note down # oa's
                if out_dict['is_oa']:
                    are_oa += 1

                successes_or_found += 1 # only reached when either doi or title query is successful
            except KeyboardInterrupt:
                print("### INTERRUPTED")
                break
            except:
    #             url = f'https://api.unpaywall.org/v2/search/?query={title_arg}&email={email}'

                fails[key] = [url, value]
                print(f"############# Calls: {calls}, Fails: {len(fails)}")

        else:
            if query_out[key]['is_oa']:
                    are_oa += 1
            successes_or_found += 1
            print(f"Call {calls} found")
            
    # Looping through the rest (100K?)
            
except KeyboardInterrupt:
    pass
        
# 5. save dict to file
with open(json_file, 'w') as fp:
    json.dump(query_out, fp)
    # vary: alter frequency of file save
    if (calls % 1 == 0):
        fp.close()
        
# Print stats
print("")
print("###### STATS ######")
print(f"Total calls: {calls}")
print(f"Total number of queries: {queries}")
print(f"Number of failed queries: {len(fails)}")
print(f"Number of open access papers: {are_oa}")
print(f"Number of papers in storage: {successes_or_found}")
print(f"% of open access papers: {are_oa / (successes_or_found+1) * 100}%")
# Out:
# Call 1 found
# Call 2 found
# Call 3 found
# Call 4 found
# Call 5 found
# Call 6 found
# Call 7 found
# Call 8 found
# Call 9 found
# ############# Calls: 10, Fails: 1
# Call 11 found
# ############# Calls: 12, Fails: 2
# Call 13 found
# Call 14 found
# Call 15 found
# Call 16 found
# Call 17 found
# Call 18 found
# Call 19 found
# Call 20 found
# ############# Calls: 21, Fails: 3
# Call 22 found
# Call 23 found
# Call 24 found
# Call 25 found
# Call 26 found
# Call 27 found
# Call 28 found
# Call 29 found
# Call 30 found
# Call 31 found
# Call 32 found
# Call 33 found
# Call 34 found
# Call 35 found
# Call 36 found
# Call 37 found
# Call 38 found
# Call 39 found
# Call 40 found
# Call 41 found
# ############# Calls: 42, Fails: 4
# Call 43 found
# Call 44 found
# #### Call 45 success
# #### Call 46 success
# #### Call 47 success
# #### Call 48 success
# #### Call 49 success
# ############# Calls: 50, Fails: 5
# #### Call 51 success
# #### Call 52 success
# ############# Calls: 53, Fails: 6
# #### Call 54 success
# #### Call 55 success
# #### Call 56 success
# #### Call 57 success
# ############# Calls: 58, Fails: 7
# #### Call 59 success
# #### Call 60 success
# #### Call 61 success
# #### Call 62 success
# #### Call 63 success
# #### Call 64 success
# #### Call 65 success
# #### Call 66 success
# #### Call 67 success
# #### Call 68 success
# #### Call 69 success
# #### Call 70 success
# #### Call 71 success
# #### Call 72 success
# #### Call 73 success
# #### Call 74 success
# #### Call 75 success
# #### Call 76 success
# #### Call 77 success
# #### Call 78 success
# #### Call 79 success
# #### Call 80 success
# #### Call 81 success
# ############# Calls: 82, Fails: 8
# #### Call 83 success
# ############# Calls: 84, Fails: 9
# #### Call 85 success
# #### Call 86 success
# #### Call 87 success
# #### Call 88 success
# #### Call 89 success
# #### Call 90 success
# #### Call 91 success
# #### Call 92 success
# #### Call 93 success
# #### Call 94 success
# #### Call 95 success
# #### Call 96 success
# #### Call 97 success
# #### Call 98 success
# #### Call 99 success
# #### Call 100 success
# #### Call 101 success
# #### Call 102 success
# #### Call 103 success
# #### Call 104 success
# #### Call 105 success
# ############# Calls: 106, Fails: 10
# #### Call 107 success
# #### Call 108 success
# ############# Calls: 109, Fails: 11
# #### Call 110 success
# ############# Calls: 111, Fails: 12
# #### Call 112 success
# ############# Calls: 113, Fails: 13
# #### Call 114 success
# #### Call 115 success
# #### Call 116 success
# #### Call 117 success
# #### Call 118 success
# ############# Calls: 119, Fails: 14
# #### Call 120 success
# ############# Calls: 121, Fails: 15
# ############# Calls: 122, Fails: 16
# ############# Calls: 123, Fails: 17
# ############# Calls: 124, Fails: 18
# #### Call 125 success
# #### Call 126 success
# ############# Calls: 127, Fails: 19
# #### Call 410 success
# #### Call 411 success
# #### Call 412 success
# #### Call 413 success
# ############# Calls: 414, Fails: 48
# #### Call 415 success
# #### Call 416 success
# #### Call 417 success
# #### Call 418 success
# #### Call 419 success
# #### Call 420 success
# #### Call 421 success
# #### Call 422 success
# #### Call 423 success
# #### Call 424 success
# #### Call 425 success
# #### Call 426 success
# #### Call 427 success
# #### Call 428 success
# #### Call 429 success
# #### Call 430 success
# #### Call 431 success
# #### Call 432 success
# #### Call 433 success
# #### Call 434 success
# #### Call 435 success
# ############# Calls: 436, Fails: 49
# #### Call 437 success
# #### Call 438 success
# #### Call 439 success
# #### Call 440 success
# #### Call 441 success
# #### Call 442 success
# ############# Calls: 443, Fails: 50
# #### Call 444 success
# #### Call 445 success
# #### Call 446 success
# #### Call 447 success
# #### Call 448 success
# #### Call 449 success
# #### Call 450 success
# #### Call 451 success
# #### Call 452 success
# #### Call 453 success
# #### Call 454 success
# #### Call 455 success
# #### Call 456 success
# #### Call 457 success
# #### Call 458 success
# #### Call 459 success
# #### Call 460 success
# #### Call 461 success
# #### Call 462 success
# #### Call 463 success
# #### Call 464 success
# #### Call 465 success
# #### Call 466 success
# #### Call 467 success
# ############# Calls: 468, Fails: 51
# ############# Calls: 469, Fails: 52
# #### Call 470 success
# #### Call 471 success
# #### Call 472 success
# #### Call 473 success
# ############# Calls: 474, Fails: 53
# #### Call 475 success
# #### Call 476 success
# #### Call 477 success
# ############# Calls: 478, Fails: 54
# #### Call 479 success
# ############# Calls: 480, Fails: 55
# #### Call 481 success
# #### Call 482 success
# ############# Calls: 483, Fails: 56
# ############# Calls: 484, Fails: 57
# #### Call 485 success
# #### Call 486 success
# ############# Calls: 487, Fails: 58
# #### Call 488 success
# #### Call 489 success
# #### Call 490 success
# #### Call 491 success
# ############# Calls: 492, Fails: 59
# #### Call 493 success
# #### Call 494 success
# #### Call 495 success
# #### Call 496 success
# ############# Calls: 497, Fails: 60
# ############# Calls: 498, Fails: 61
# #### Call 499 success
# #### Call 500 success
# #### Call 501 success
# #### Call 502 success
# #### Call 503 success
# #### Call 504 success
# #### Call 505 success
# #### Call 506 success
# #### Call 507 success
# #### Call 508 success
# #### Call 509 success
# ############# Calls: 510, Fails: 62
# ############# Calls: 511, Fails: 63
# #### Call 512 success
# #### Call 513 success
# #### Call 514 success
# #### Call 515 success
# #### Call 516 success
# #### Call 517 success
# #### Call 518 success
# ############# Calls: 519, Fails: 64
# #### Call 520 success
# #### Call 521 success
# #### Call 522 success
# #### Call 523 success
# #### Call 524 success
# #### Call 525 success
# #### Call 526 success
# #### Call 527 success
# #### Call 528 success
# #### Call 529 success
# #### Call 530 success
# ############# Calls: 531, Fails: 65
# #### Call 532 success
# #### Call 533 success
# ############# Calls: 534, Fails: 66
# #### Call 535 success
# #### Call 536 success
# ############# Calls: 537, Fails: 67
# #### Call 538 success
# #### Call 539 success
# ############# Calls: 540, Fails: 68
# #### Call 541 success
# #### Call 542 success
# #### Call 543 success
# #### Call 544 success
# #### Call 545 success
# #### Call 546 success
# #### Call 547 success
# #### Call 548 success
# #### Call 549 success
# #### Call 550 success
# #### Call 551 success
# #### Call 552 success
# #### Call 553 success
# #### Call 554 success
# ############# Calls: 555, Fails: 69
# #### Call 556 success
# #### Call 557 success
# ############# Calls: 558, Fails: 70
# #### Call 559 success
# #### Call 560 success
# #### Call 561 success
# #### Call 562 success
# #### Call 563 success
# #### Call 564 success
# #### Call 565 success
# #### Call 566 success
# #### Call 567 success
# ############# Calls: 568, Fails: 71
# #### Call 569 success
# #### Call 570 success
# #### Call 571 success
# #### Call 572 success
# #### Call 573 success
# ############# Calls: 574, Fails: 72
# #### Call 575 success
# #### Call 576 success
# #### Call 577 success
# #### Call 578 success
# #### Call 579 success
# #### Call 580 success
# #### Call 581 success
# #### Call 582 success
# #### Call 583 success
# #### Call 584 success
# #### Call 585 success
# #### Call 586 success
# #### Call 587 success
# #### Call 588 success
# #### Call 589 success
# #### Call 590 success
# #### Call 591 success
# #### Call 592 success
# #### Call 593 success
# ############# Calls: 594, Fails: 73
# ############# Calls: 595, Fails: 74
# #### Call 596 success
# ############# Calls: 597, Fails: 75
# #### Call 598 success
# #### Call 599 success
# #### Call 600 success
# #### Call 601 success
# #### Call 602 success
# #### Call 603 success
# #### Call 604 success
# #### Call 605 success
# #### Call 606 success
# #### Call 607 success
# #### Call 608 success
# #### Call 609 success
# #### Call 610 success
# #### Call 611 success
# #### Call 612 success
# #### Call 613 success
# #### Call 614 success
# #### Call 615 success
# #### Call 616 success
# #### Call 617 success
# #### Call 618 success
# #### Call 619 success
# #### Call 620 success
# #### Call 621 success
# #### Call 622 success
# #### Call 623 success
# ############# Calls: 624, Fails: 76
# #### Call 625 success
# #### Call 626 success
# #### Call 627 success
# #### Call 628 success
# ############# Calls: 629, Fails: 77
# ############# Calls: 630, Fails: 78
# #### Call 631 success
# #### Call 632 success
# #### Call 633 success
# #### Call 634 success
# #### Call 635 success
# #### Call 636 success
# #### Call 637 success
# #### Call 638 success
# #### Call 639 success
# ############# Calls: 640, Fails: 79
# #### Call 641 success
# #### Call 642 success
# #### Call 643 success
# #### Call 644 success
# #### Call 645 success
# #### Call 646 success
# #### Call 647 success
# #### Call 648 success
# #### Call 649 success
# #### Call 650 success
# ############# Calls: 651, Fails: 80
# #### Call 652 success
# #### Call 653 success
# #### Call 654 success
# #### Call 655 success
# ############# Calls: 656, Fails: 81
# ############# Calls: 657, Fails: 82
# #### Call 658 success
# #### Call 659 success
# #### Call 660 success
# #### Call 661 success
# #### Call 662 success
# #### Call 663 success
# #### Call 664 success
# #### Call 665 success
# ############# Calls: 666, Fails: 83
# #### Call 667 success
# #### Call 668 success
# #### Call 669 success
# #### Call 670 success
# #### Call 671 success
# #### Call 672 success
# #### Call 673 success
# #### Call 674 success
# #### Call 675 success
# #### Call 676 success
# #### Call 677 success
# #### Call 678 success
# #### Call 679 success
# #### Call 680 success
# ############# Calls: 681, Fails: 84
# #### Call 682 success
# #### Call 683 success
# ############# Calls: 684, Fails: 85
# #### Call 685 success
# #### Call 686 success
# #### Call 687 success
# #### Call 688 success
# ############# Calls: 689, Fails: 86
# #### Call 690 success
# #### Call 691 success
# #### Call 692 success
# ############# Calls: 693, Fails: 87
# #### Call 694 success
# #### Call 695 success
# #### Call 696 success
# #### Call 697 success
# #### Call 698 success
# #### Call 699 success
# #### Call 700 success
# #### Call 701 success
# #### Call 702 success
# #### Call 703 success
# #### Call 704 success
# #### Call 705 success
# #### Call 706 success
# #### Call 707 success
# #### Call 708 success
# #### Call 709 success
# #### Call 710 success
# #### Call 711 success
# #### Call 712 success
# #### Call 713 success
# #### Call 714 success
# ############# Calls: 715, Fails: 88
# #### Call 716 success
# ############# Calls: 717, Fails: 89
# ############# Calls: 718, Fails: 90
# #### Call 719 success
# #### Call 720 success
# #### Call 721 success
# #### Call 722 success
# #### Call 723 success
# #### Call 724 success
# #### Call 725 success
# #### Call 726 success
# #### Call 727 success
# #### Call 728 success
# #### Call 729 success
# #### Call 730 success
# #### Call 731 success
# #### Call 732 success
# #### Call 733 success
# ############# Calls: 734, Fails: 91
# #### Call 735 success
# #### Call 736 success
# #### Call 737 success
# #### Call 738 success
# #### Call 739 success
# ############# Calls: 740, Fails: 92
# #### Call 741 success
# #### Call 742 success
# #### Call 743 success
# #### Call 744 success
# ############# Calls: 745, Fails: 93
# #### Call 746 success
# #### Call 747 success
# #### Call 748 success
# #### Call 749 success
# #### Call 750 success
# #### Call 751 success
# #### Call 752 success
# #### Call 753 success
# #### Call 754 success
# #### Call 755 success
# #### Call 756 success
# #### Call 757 success
# #### Call 758 success
# #### Call 759 success
# #### Call 760 success
# #### Call 761 success
# #### Call 762 success
# #### Call 763 success
# #### Call 764 success
# #### Call 765 success
# #### Call 766 success
# ############# Calls: 767, Fails: 94
# #### Call 768 success
# #### Call 769 success
# #### Call 770 success
# ############# Calls: 771, Fails: 95
# #### Call 772 success
# #### Call 773 success
# #### Call 774 success
# #### Call 775 success
# #### Call 776 success
# #### Call 777 success
# #### Call 778 success
# ############# Calls: 779, Fails: 96
# #### Call 780 success
# #### Call 781 success
# #### Call 782 success
# #### Call 783 success
# #### Call 784 success
# #### Call 785 success
# #### Call 786 success
# #### Call 787 success
# #### Call 788 success
# #### Call 789 success
# #### Call 790 success
# #### Call 791 success
# #### Call 792 success
# #### Call 793 success
# #### Call 794 success
# ############# Calls: 795, Fails: 97
# #### Call 796 success
# ############# Calls: 797, Fails: 98
# ############# Calls: 798, Fails: 99
# #### Call 799 success
# #### Call 800 success
# ############# Calls: 801, Fails: 100
# ############# Calls: 802, Fails: 101
# #### Call 803 success
# ############# Calls: 804, Fails: 102
# #### Call 805 success
# #### Call 806 success
# ############# Calls: 807, Fails: 103
# #### Call 808 success
# #### Call 809 success
# #### Call 810 success
# #### Call 811 success
# #### Call 812 success
# #### Call 813 success
# #### Call 814 success
# #### Call 815 success
# #### Call 816 success
# #### Call 817 success
# #### Call 818 success
# #### Call 819 success
# #### Call 820 success
# #### Call 821 success
# #### Call 2007 success
# #### Call 2008 success
# #### Call 2009 success
# ############# Calls: 2010, Fails: 213
# ############# Calls: 2011, Fails: 214
# #### Call 2012 success
# ...
# #### Call 11463 success
# #### Call 11464 success
# #### Call 11465 success
# #### Call 11466 success
# #### Call 11467 success
# #### Call 11468 success
# #### Call 11469 success
# #### Call 11470 success
# #### Call 11471 success
# #### Call 11472 success
# #### Call 11473 success
# #### Call 11474 success
# #### Call 11475 success
# #### Call 11476 success
# #### Call 11477 success
# #### Call 11478 success
# #### Call 11479 success
# ############# Calls: 11480, Fails: 1577
# #### Call 11481 success
# #### Call 11482 success
# #### Call 11483 success
# #### Call 11484 success
# ############# Calls: 11485, Fails: 1578
# #### Call 11486 success
# #### Call 11487 success
# #### Call 11488 success
# #### Call 11489 success
# #### Call 11490 success
# #### Call 11491 success
# #### Call 11492 success
# #### Call 11493 success
# #### Call 11494 success
# #### Call 11495 success
# #### Call 11496 success
# #### Call 11497 success
# #### Call 11498 success
# #### Call 11499 success
# #### Call 11500 success
# #### Call 11501 success
# #### Call 11502 success
# #### Call 11503 success
# #### Call 11504 success
# #### Call 11505 success
# #### Call 11506 success
# #### Call 11507 success
# #### Call 11508 success
# #### Call 11509 success
# #### Call 11510 success
# #### Call 11511 success
# ############# Calls: 11512, Fails: 1579
# #### Call 11513 success
# ############# Calls: 11514, Fails: 1580
# #### Call 11515 success
# #### Call 11516 success
# #### Call 11517 success
# #### Call 11518 success
# #### Call 11519 success
# #### Call 11520 success
# #### Call 11521 success
# #### Call 11522 success
# #### Call 11523 success
# #### Call 11524 success
# #### Call 11525 success
# #### Call 11526 success
# #### Call 11527 success
# #### Call 11528 success
# ############# Calls: 11529, Fails: 1581
# #### Call 11530 success
# ############# Calls: 11531, Fails: 1582
# #### Call 11532 success
# #### Call 11533 success
# #### Call 11534 success
# #### Call 11535 success
# #### Call 11536 success
# #### Call 11537 success
# #### Call 11538 success
# #### Call 11539 success
# #### Call 11540 success
# #### Call 11541 success
# #### Call 11542 success
# #### Call 11543 success
# #### Call 11544 success
# #### Call 11545 success
# #### Call 11546 success
# #### Call 11547 success
# ############# Calls: 11548, Fails: 1583
# #### Call 11549 success
# #### Call 11550 success
# #### Call 11551 success
# #### Call 11552 success
# ############# Calls: 11553, Fails: 1584
# #### Call 11554 success
# #### Call 11555 success
# #### Call 11556 success
# #### Call 11557 success
# ############# Calls: 11558, Fails: 1585
# #### Call 11559 success
# #### Call 11560 success
# #### Call 11561 success
# #### Call 11562 success
# #### Call 11563 success
# #### Call 11564 success
# #### Call 11565 success
# #### Call 11566 success
# #### Call 11567 success
# #### Call 11568 success
# #### Call 11569 success
# #### Call 11570 success
# #### Call 11571 success
# ############# Calls: 11572, Fails: 1586
# #### Call 11573 success
# #### Call 11574 success
# #### Call 11575 success
# #### Call 11576 success
# #### Call 11577 success
# #### Call 11578 success
# #### Call 11579 success
# #### Call 11580 success
# #### Call 11581 success
# ############# Calls: 11582, Fails: 1587
# ############# Calls: 11583, Fails: 1588
# #### Call 11584 success
# #### Call 11585 success
# #### Call 11586 success
# #### Call 11587 success
# #### Call 11588 success
# #### Call 11589 success
# #### Call 11590 success
# #### Call 11591 success
# #### Call 11592 success
# #### Call 11593 success
# #### Call 11594 success
# #### Call 11595 success
# #### Call 11596 success
# #### Call 11597 success
# #### Call 11598 success
# #### Call 11599 success
# ############# Calls: 11600, Fails: 1589
# ############# Calls: 11601, Fails: 1590
# #### Call 11602 success
# #### Call 11603 success
# #### Call 11604 success
# #### Call 11605 success
# #### Call 11606 success
# #### Call 11607 success
# #### Call 11608 success
# #### Call 11609 success
# ############# Calls: 11610, Fails: 1591
# #### Call 11611 success
# #### Call 11612 success
# #### Call 11613 success
# #### Call 11614 success
# #### Call 11615 success
# #### Call 11616 success
# #### Call 11617 success
# #### Call 11618 success
# #### Call 11619 success
# #### Call 11620 success
# #### Call 11621 success
# #### Call 11622 success
# #### Call 11623 success
# #### Call 11624 success
# #### Call 11625 success
# #### Call 11626 success
# #### Call 11627 success
# #### Call 11628 success
# #### Call 11629 success
# #### Call 11630 success
# #### Call 11631 success
# #### Call 11632 success
# #### Call 11633 success
# #### Call 11634 success
# #### Call 11635 success
# #### Call 11636 success
# #### Call 11637 success
# #### Call 11638 success
# #### Call 11639 success
# #### Call 11640 success
# #### Call 11641 success
# #### Call 11642 success
# ############# Calls: 11643, Fails: 1592
# #### Call 11644 success
# #### Call 11645 success
# ############# Calls: 11646, Fails: 1593
# #### Call 11647 success
# #### Call 11648 success
# #### Call 11649 success
# #### Call 11650 success
# #### Call 11651 success
# #### Call 11652 success
# #### Call 11653 success
# #### Call 11654 success
# #### Call 11655 success
# #### Call 11656 success
# #### Call 11657 success
# ############# Calls: 11658, Fails: 1594
# #### Call 11659 success
# ############# Calls: 11660, Fails: 1595
# #### Call 11661 success
# #### Call 11662 success
# #### Call 11663 success
# ############# Calls: 11664, Fails: 1596
# #### Call 11665 success
# #### Call 11666 success
# #### Call 11667 success
# #### Call 11668 success
# #### Call 11669 success
# #### Call 11670 success
# #### Call 11671 success
# #### Call 11672 success
# #### Call 11673 success
# #### Call 11674 success
# #### Call 11675 success
# #### Call 11676 success
# #### Call 11677 success
# #### Call 11678 success
# #### Call 11679 success
# #### Call 11680 success
# #### Call 11681 success
# #### Call 11682 success
# #### Call 11683 success
# #### Call 11684 success
# #### Call 11685 success
# #### Call 11686 success
# #### Call 11687 success
# #### Call 11688 success
# #### Call 11689 success
# #### Call 11690 success
# #### Call 11691 success
# #### Call 11692 success
# #### Call 11693 success
# #### Call 11694 success
# ############# Calls: 11695, Fails: 1597
# ############# Calls: 11696, Fails: 1598
# #### Call 11697 success
# #### Call 11698 success
# ############# Calls: 11699, Fails: 1599
# #### Call 11700 success
# ############# Calls: 11701, Fails: 1600
# #### Call 11702 success
# #### Call 11703 success
# #### Call 11704 success
# #### Call 11705 success
# #### Call 11706 success
# ############# Calls: 11707, Fails: 1601
# #### Call 11708 success
# #### Call 11709 success
# #### Call 11710 success
# ############# Calls: 11711, Fails: 1602
# #### Call 11712 success
# #### Call 11713 success
# ############# Calls: 11714, Fails: 1603
# ############# Calls: 11715, Fails: 1604
# #### Call 11716 success
# #### Call 11717 success
# #### Call 11718 success
# #### Call 11719 success
# #### Call 11720 success
# #### Call 11721 success
# #### Call 11722 success
# #### Call 11723 success
# #### Call 11724 success
# ############# Calls: 11725, Fails: 1605
# ############# Calls: 11726, Fails: 1606
# #### Call 11727 success
# ############# Calls: 11728, Fails: 1607
# #### Call 11729 success
# #### Call 11730 success
# #### Call 11731 success
# #### Call 11732 success
# #### Call 11733 success
# ############# Calls: 11734, Fails: 1608
# ############# Calls: 11735, Fails: 1609
# #### Call 11736 success
# #### Call 11737 success
# ############# Calls: 11738, Fails: 1610
# #### Call 11739 success
# #### Call 11740 success
# #### Call 11741 success
# #### Call 11742 success
# #### Call 11743 success
# ############# Calls: 11744, Fails: 1611
# #### Call 11745 success
# ############# Calls: 11746, Fails: 1612
# ############# Calls: 11747, Fails: 1613
# #### Call 11748 success
# ############# Calls: 11749, Fails: 1614
# #### Call 11750 success
# #### Call 11751 success
# ############# Calls: 11752, Fails: 1615
# #### Call 11753 success
# #### Call 11754 success
# #### Call 11755 success
# #### Call 11756 success
# #### Call 11757 success
# ############# Calls: 11758, Fails: 1616
# ############# Calls: 11759, Fails: 1617
# #### Call 11760 success
# #### Call 11761 success
# #### Call 11762 success
# #### Call 11763 success
# #### Call 11764 success
# #### Call 11765 success
# #### Call 11766 success
# #### Call 11767 success
# #### Call 11768 success
# #### Call 11769 success
# #### Call 11770 success
# #### Call 11771 success
# #### Call 11772 success
# ############# Calls: 11773, Fails: 1618
# #### Call 11774 success
# #### Call 11775 success
# #### Call 11776 success
# ############# Calls: 11777, Fails: 1619
# #### Call 11778 success
# #### Call 11779 success
# #### Call 11780 success
# #### Call 11781 success
# #### Call 11782 success
# #### Call 11783 success
# #### Call 11784 success
# #### Call 11785 success
# #### Call 11786 success
# #### Call 11787 success
# #### Call 11788 success
# #### Call 11789 success
# #### Call 11790 success
# #### Call 11791 success
# #### Call 11792 success
# #### Call 11793 success
# ############# Calls: 11794, Fails: 1620
# ############# Calls: 11795, Fails: 1621
# #### Call 11796 success
# #### Call 11797 success
# #### Call 11798 success
# #### Call 11799 success
# #### Call 11800 success
# #### Call 11801 success
# #### Call 11802 success
# #### Call 11803 success
# #### Call 11804 success
# #### Call 11805 success
# ############# Calls: 11806, Fails: 1622
# #### Call 11807 success
# #### Call 11808 success
# #### Call 11809 success
# #### Call 11810 success
# #### Call 11811 success
# #### Call 11812 success
# #### Call 11813 success
# #### Call 11814 success
# #### Call 11815 success
# #### Call 11816 success
# #### Call 11817 success
# #### Call 11818 success
# #### Call 11819 success
# #### Call 11820 success
# ############# Calls: 11821, Fails: 1623
# #### Call 11822 success
# #### Call 11823 success
# #### Call 11824 success
# #### Call 11825 success
# #### Call 11826 success
# #### Call 11827 success
# #### Call 11828 success
# ############# Calls: 11829, Fails: 1624
# ############# Calls: 11830, Fails: 1625
# #### Call 11831 success
# #### Call 11832 success
# #### Call 11833 success
# #### Call 11834 success
# #### Call 11835 success
# #### Call 11836 success
# #### Call 11837 success
# ############# Calls: 11838, Fails: 1626
# ############# Calls: 11839, Fails: 1627
# ############# Calls: 11840, Fails: 1628
# #### Call 11841 success
# #### Call 11842 success
# #### Call 11843 success
# #### Call 11844 success
# ############# Calls: 11845, Fails: 1629
# #### Call 11846 success
# #### Call 11847 success
# #### Call 11848 success
# ############# Calls: 11849, Fails: 1630
# #### Call 11850 success
# #### Call 11851 success
# #### Call 11852 success
# #### Call 11853 success
# ############# Calls: 11854, Fails: 1631
# ############# Calls: 11855, Fails: 1632
# ############# Calls: 11856, Fails: 1633
# #### Call 11857 success
# ############# Calls: 11858, Fails: 1634
# #### Call 11859 success
# #### Call 11860 success
# #### Call 11861 success
# ############# Calls: 11862, Fails: 1635
# #### Call 11863 success
# ############# Calls: 11864, Fails: 1636
# ############# Calls: 11865, Fails: 1637
# #### Call 11866 success
# #### Call 11867 success
# ############# Calls: 11868, Fails: 1638
# #### Call 11869 success
# #### Call 11870 success
# #### Call 11871 success
# #### Call 11872 success
# #### Call 11873 success
# #### Call 11874 success
# #### Call 11875 success
# #### Call 11876 success
# #### Call 11877 success
# #### Call 11878 success
# #### Call 11879 success
# #### Call 11880 success
# #### Call 11881 success
# #### Call 11882 success
# #### Call 11883 success
# #### Call 11884 success
# #### Call 11885 success
# #### Call 11886 success
# #### Call 11887 success
# #### Call 11888 success
# #### Call 11889 success
# #### Call 11890 success
# #### Call 11891 success
# #### Call 11892 success
# ############# Calls: 11893, Fails: 1639
# #### Call 11894 success
# #### Call 11895 success
# #### Call 11896 success
# ############# Calls: 11897, Fails: 1640
# ############# Calls: 11898, Fails: 1641
# #### Call 11899 success
# #### Call 11900 success
# #### Call 11901 success
# ############# Calls: 11902, Fails: 1642
# #### Call 11903 success
# #### Call 11904 success
# #### Call 11905 success
# #### Call 11906 success
# #### Call 11907 success
# #### Call 11908 success
# #### Call 11909 success
# ############# Calls: 11910, Fails: 1643
# ############# Calls: 11911, Fails: 1644
# #### Call 11912 success
# #### Call 11913 success
# #### Call 11914 success
# #### Call 11915 success
# #### Call 11916 success
# #### Call 11917 success
# #### Call 11918 success
# ############# Calls: 11919, Fails: 1645
# #### Call 11920 success
# #### Call 11921 success
# #### Call 11922 success
# ############# Calls: 11923, Fails: 1646
# #### Call 11924 success
# #### Call 11925 success
# #### Call 11926 success
# #### Call 11927 success
# #### Call 11928 success
# #### Call 11929 success
# #### Call 11930 success
# #### Call 11931 success
# #### Call 11932 success
# #### Call 11933 success
# #### Call 11934 success
# #### Call 11935 success
# #### Call 11936 success
# #### Call 11937 success
# #### Call 11938 success
# #### Call 11939 success
# #### Call 11940 success
# #### Call 11941 success
# #### Call 11942 success
# #### Call 11943 success
# #### Call 11944 success
# #### Call 11945 success
# #### Call 11946 success
# #### Call 11947 success
# #### Call 11948 success
# #### Call 11949 success
# #### Call 11950 success
# #### Call 11951 success
# ############# Calls: 11952, Fails: 1647
# #### Call 11953 success
# #### Call 11954 success
# #### Call 11955 success
# #### Call 11956 success
# #### Call 11957 success
# #### Call 11958 success
# #### Call 11959 success
# #### Call 11960 success
# #### Call 11961 success
# #### Call 11962 success
# #### Call 11963 success
# #### Call 11964 success
# #### Call 11965 success
# #### Call 11966 success
# #### Call 11967 success
# #### Call 11968 success
# #### Call 11969 success
# #### Call 11970 success
# #### Call 11971 success
# #### Call 11972 success
# #### Call 11973 success
# #### Call 11974 success
# #### Call 11975 success
# #### Call 11976 success
# #### Call 11977 success
# #### Call 11978 success
# #### Call 11979 success
# #### Call 11980 success
# #### Call 11981 success
# #### Call 11982 success
# #### Call 11983 success
# ############# Calls: 11984, Fails: 1648
# #### Call 11985 success
# #### Call 11986 success
# #### Call 11987 success
# ############# Calls: 11988, Fails: 1649
# #### Call 11989 success
# #### Call 11990 success
# #### Call 11991 success
# #### Call 11992 success
# #### Call 11993 success
# ############# Calls: 11994, Fails: 1650
# #### Call 11995 success
# #### Call 11996 success
# #### Call 11997 success
# #### Call 11998 success
# #### Call 11999 success
# #### Call 12000 success
# #### Call 12001 success
# #### Call 12002 success
# #### Call 12003 success
# #### Call 12004 success
# #### Call 12005 success
# #### Call 12006 success
# #### Call 12007 success
# #### Call 12008 success
# #### Call 12009 success
# #### Call 12010 success
# #### Call 12011 success
# #### Call 12012 success
# #### Call 12013 success
# ############# Calls: 12014, Fails: 1651
# #### Call 12015 success
# #### Call 12016 success
# #### Call 12017 success
# #### Call 12018 success
# #### Call 12019 success
# ############# Calls: 12020, Fails: 1652
# #### Call 12021 success
# #### Call 12022 success
# #### Call 12023 success
# #### Call 12024 success
# #### Call 12025 success
# #### Call 12026 success
# #### Call 12027 success
# #### Call 12028 success
# #### Call 12029 success
# #### Call 12030 success
# #### Call 12031 success
# ############# Calls: 12032, Fails: 1653
# #### Call 12033 success
# #### Call 12034 success
# #### Call 12035 success
# #### Call 12036 success
# ############# Calls: 12037, Fails: 1654
# #### Call 12038 success
# #### Call 12039 success
# #### Call 12040 success
# #### Call 12041 success
# #### Call 12042 success
# ############# Calls: 12043, Fails: 1655
# #### Call 12044 success
# #### Call 12045 success
# #### Call 12046 success
# #### Call 12047 success
# ############# Calls: 12048, Fails: 1656
# #### Call 12049 success
# #### Call 12050 success
# #### Call 12051 success
# #### Call 12052 success
# #### Call 12053 success
# #### Call 12054 success
# ############# Calls: 12055, Fails: 1657
# #### Call 12056 success
# #### Call 12057 success
# #### Call 12058 success
# ############# Calls: 12059, Fails: 1658
# #### Call 12060 success
# #### Call 12061 success
# ############# Calls: 12062, Fails: 1659
# #### Call 12063 success
# #### Call 12064 success
#
# ###### STATS ######
# Total calls: 12064
# Total number of queries: 13195
# Number of failed queries: 1659
# Number of open access papers: 2127
# Number of papers in storage: 10398
# % of open access papers: 20.453889797095876%

# %% [markdown]
# ## Getting PMID -> DOI -> Query (not refDict).
# ~100K unique PMIDs.

# %%
# remove all duplicates and zeroes. 
pmids = pd.read_csv("../Data_CSVs/brenda_rxns_incomplete.csv").pubmedId
pmids = pmids.drop_duplicates().dropna()
pmids = pmids.apply(lambda x: str(math.floor(x)) if x != 0 else None)
pmids = pmids.drop_duplicates().dropna()
len(pmids)

# %% [markdown]
# Converts PMID to DOI using PubMed API

# %%
import re

def doi_from_pmid(pmid):
    url = f'https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/?tool=id_converter_api&email={email}&ids={pmid}'
    data = requests.get(url).content.decode("utf-8") 
    match =  re.findall('doi="([^"]*)', data)
    if match:
        return match[0]
    return False
        
doi_from_pmid(19022233)

# %% [markdown]
# CANT GET THIS TO WORK

# %%
url = 'https://www.pmid2cite.com/pmid-to-doi-converter'
myobj = {'pmidNo': '11056675'}

x = requests.post(url, data= myobj)

print(x.text)

# %%
# LOOP AND QUERY

# Check if json file is saved. Create or load a dict!!
json_file = './quantify_datasets/query_out_pmid.json'
if os.path.isfile(json_file):
    with open(json_file, 'r') as fp:
        query_out = json.load(fp)
        fp.close()
else:
    query_out = {}
    
# stats
pmid_max_calls = 100 #False #90000 # max 100K per day (to be safe); or False if querying all.
pmid_calls = 0
pmid_queries = 0
pmid_fail_no_doi = [] # pmid strings
pmid_fail_no_result = {} # pmid: [doi, url]
pmid_are_oa = 0
pmid_successes_or_found = 0
    
##### MAIN LOOP #####
try: 
    for pmid in pmids:
        # stop before maxing out query
        if pmid_calls == pmid_max_calls or (pmid_queries == 99999):
            print("Query limit reached.")
            break
        else:
            pmid_calls += 1
            
        # checks if pmid has been succcessful before.
        if pmid in query_out:
            successes_or_found += 1
            print(f"Call {pmid_calls} found")
            continue
            
        # query
        if doi := doi_from_pmid(pmid):
            url = f'https://api.unpaywall.org/v2/{doi}?email={email}'
            out_dict = requests.get(url).json()
            pmid_queries += 1
            
            #backup
            if !out_dict:
                url = 'https://www.w3schools.com/python/demopage.php'
                myobj = {'somekey': 'somevalue'}

                x = requests.post(url, data = myobj)

                print(x.text)
            
            # 4. append to DICT if successful
            if out_dict:
                query_out[pmid] = out_dict
                print(f"## Call {pmid_calls} success")
                pmid_successes_or_found += 1 # only reached when either doi or title query is successful
            else:
                print(f"####### Call {pmid_calls} failed. No results.")

            # Extra: note down # oa's
            if out_dict['is_oa']:
                pmid_are_oa += 1

        else: # if doi isnt available
            print(f"#### Call {pmid_calls} failed. No DOI found.")
            pmid_fail_no_doi.append(pmid)
            
except KeyboardInterrupt:
    pass

# 5. save dict to file
with open(json_file, 'w') as fp:
    json.dump(query_out, fp)
    # vary: alter frequency of file save
    if (calls % 1 == 0):
        fp.close()
        
# Print stats
print("")
print("###### STATS ######")
print(f"Total calls: {pmid_calls}")
print(f"Total number of queries: {pmid_queries}")
print(f"Number of failed doi lookups: {len(pmid_fail_no_doi)}")
print(f"Number of failed queries: {len(pmid_fail_no_result)}")
print(f"Number of open access papers: {pmid_are_oa}")
print(f"Number of papers in storage: {pmid_successes_or_found}")
print(f"% of open access papers: {pmid_are_oa / (pmid_successes_or_found+1) * 100}%")

# %%
pmid_fail_no_doi
