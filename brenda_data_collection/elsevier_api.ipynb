# %% [markdown]
# ## Elsevier API
# Goal: Get % of refDict that can be found through the Elsevier API. Assume OA's from Unpaywall does not overlap with Elsevier papers (they practically don't)
#
# Dependency: quantify_datasets/query_out.json
#
# Source: https://raw.githubusercontent.com/ElsevierDev/elsapy/master/exampleProg.py

# %%
import urllib
import requests
import os
import math
import json
import pandas as pd

from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch
import json

email = 'ivalexander13@berkeley.edu' # enter ur email pls

# %% [markdown]
# Elsevier Setup

# %%
## Load configuration
con_file = open("elsevier_api/config.json")
config = json.load(con_file)
con_file.close()

## Initialize client
client = ElsClient(config['apikey'])
client.local_dir = "./elsevier_api/"

# %%
# Load the metadata
json_file = './quantify_datasets/query_out.json'
if os.path.isfile(json_file):
    with open(json_file, 'r') as fp:
        query_out = json.load(fp)
        fp.close()

# %%
# Get paper
def get_paper(doi: str):
    ## ScienceDirect (full-text) document example using DOI
    doi_doc = FullDoc(doi = doi)
    if doi_doc.read(client):
        return doi_doc.data
    else:
        return False

# %%
# fixme test
get_paper('10.1016/0031-9422(73)80493-5');

# %%
# Output file = doi to full_text dict dictionary (in json)
json_file = './elsevier_api/elsevier_fulltexts.json'
if os.path.isfile(json_file):
    with open(json_file, 'r') as fp:
        elsevier_fulltexts = json.load(fp)
        fp.close()
else:
    elsevier_fulltexts = {}

# hyperparam (-1 if max)
max_calls = -1

# Stats
calls = 0
fails = 0
not_elsevier = 0
successes_or_found = 0
queries = 0

try:
    # Looping through quantify_dataset output json.
    for key, value in query_out.items():
        doi = value['doi']
        doi_url = value['doi_url']
        
        # dont go over max calls. (-1 if infinite)
        if calls == max_calls or (queries == 99999):
            print("Query limit reached.")
            break
        else:
            calls += 1

        # checks if paper has been successfully fetched before
        if doi in elsevier_fulltexts:
            successes_or_found += 1
            print(f"## Call {calls} found.")
            continue
        
        # checks if publisher is elsevier
        if value['publisher'] != 'Elsevier' and value['publisher'] != 'Elsevier BV':
            not_elsevier += 1
            continue
        
        if (fullpaper := get_paper(doi)):
            elsevier_fulltexts[doi] = fullpaper
            successes_or_found += 1
            queries += 1
            print(f"Call {calls} success.")
        else:
            fails += 1
            print (f"##### Call {calls} failed: {fails}. DOI: {doi_url}.")
        
except KeyboardInterrupt:
    pass

# save to file
with open(json_file, 'w') as fp:
    json.dump(elsevier_fulltexts, fp)
    # vary: alter frequency of file save
    if (calls % 1 == 0):
        fp.close()

# Print Stats
print("")
print("###### STATS ######")
print(f"Total calls: {calls}")
print(f"Total number of queries: {queries}")
print(f"Total number of Elsevier papers: {calls - not_elsevier}")
print(f"Number of Non-Elsevier papers skipped: {not_elsevier}")
print(f"Number of fetch failures: {fails}")
print(f"Papers in storage: {len(elsevier_fulltexts)}")
print(f"% of success: {successes_or_found / (calls-not_elsevier) * 100}%")
# Out:
# ## Call 3 found.
# ## Call 6 found.
# ## Call 7 found.
# ## Call 8 found.
# ## Call 9 found.
# ## Call 14 found.
# ## Call 16 found.
# ## Call 17 found.
# ## Call 19 found.
# ## Call 20 found.
# ## Call 21 found.
# ## Call 22 found.
# ## Call 23 found.
# ## Call 24 found.
# ## Call 25 found.
# ## Call 26 found.
# ## Call 37 found.
# ## Call 39 found.
# ## Call 42 found.
# ## Call 43 found.
# ## Call 44 found.
# ## Call 47 found.
# ## Call 51 found.
# ## Call 53 found.
# ## Call 54 found.
# ## Call 55 found.
# ## Call 58 found.
# ## Call 59 found.
# ## Call 63 found.
# ## Call 64 found.
# ## Call 67 found.
# ## Call 72 found.
# ## Call 75 found.
# ## Call 78 found.
# ## Call 79 found.
# ## Call 83 found.
# ## Call 85 found.
# ## Call 90 found.
# ## Call 95 found.
# ## Call 96 found.
# ## Call 97 found.
# ## Call 98 found.
# ## Call 102 found.
# ## Call 108 found.
# ## Call 109 found.
# ## Call 110 found.
# ## Call 111 found.
# ## Call 112 found.
# ## Call 114 found.
# ## Call 115 found.
# ## Call 119 found.
# ## Call 120 found.
# ## Call 122 found.
# ## Call 123 found.
# ## Call 128 found.
# ## Call 129 found.
# ## Call 130 found.
# ## Call 133 found.
# ## Call 135 found.
# ## Call 143 found.
# ## Call 146 found.
# ## Call 149 found.
# ## Call 151 found.
# ## Call 154 found.
# ## Call 159 found.
# ## Call 165 found.
# ## Call 166 found.
# ## Call 167 found.
# ## Call 169 found.
# ## Call 170 found.
# ## Call 175 found.
# ## Call 179 found.
# ## Call 180 found.
# ## Call 182 found.
# ## Call 184 found.
# ## Call 192 found.
# ## Call 194 found.
# ## Call 198 found.
# ## Call 199 found.
# ## Call 202 found.
# ## Call 203 found.
# ## Call 204 found.
# ## Call 207 found.
# ## Call 212 found.
# ## Call 214 found.
# ## Call 216 found.
# ## Call 217 found.
# ## Call 221 found.
# ## Call 224 found.
# ## Call 232 found.
# ## Call 234 found.
# ## Call 235 found.
# ## Call 237 found.
# ## Call 238 found.
# ## Call 239 found.
# ## Call 240 found.
# ## Call 241 found.
# ## Call 242 found.
# ## Call 243 found.
# ## Call 244 found.
# ## Call 245 found.
# ## Call 246 found.
# ## Call 247 found.
# ## Call 251 found.
# ## Call 253 found.
# ## Call 255 found.
# ## Call 257 found.
# ## Call 258 found.
# ## Call 261 found.
# ## Call 270 found.
# ## Call 271 found.
# ## Call 276 found.
# ## Call 277 found.
# ## Call 278 found.
# ## Call 280 found.
# ## Call 281 found.
# ## Call 282 found.
# ## Call 283 found.
# ## Call 287 found.
# ## Call 290 found.
# ## Call 291 found.
# ## Call 293 found.
# ## Call 295 found.
# ## Call 297 found.
# ## Call 300 found.
# ##### Call 302 failed: 1. DOI: https://doi.org/10.1016/s0031-9422(00)82076-2.
# ## Call 308 found.
# ## Call 309 found.
# ## Call 311 found.
# ## Call 312 found.
# ## Call 315 found.
# ## Call 318 found.
# ## Call 320 found.
# ## Call 324 found.
# ## Call 326 found.
# ## Call 327 found.
# ## Call 332 found.
# ## Call 336 found.
# ## Call 337 found.
# ## Call 339 found.
# ## Call 340 found.
# ## Call 342 found.
# ## Call 346 found.
# ## Call 350 found.
# ## Call 362 found.
# ## Call 366 found.
# ## Call 368 found.
# ## Call 369 found.
# ## Call 370 found.
# ## Call 372 found.
# ## Call 374 found.
# ## Call 375 found.
# ## Call 378 found.
# ## Call 379 found.
# ## Call 380 found.
# ## Call 384 found.
# ## Call 391 found.
# ## Call 393 found.
# ## Call 397 found.
# ## Call 400 found.
# ## Call 401 found.
# ## Call 402 found.
# ## Call 405 found.
# ## Call 406 found.
# ## Call 408 found.
# ## Call 410 found.
# ## Call 411 found.
# ## Call 413 found.
# ## Call 414 found.
# ## Call 415 found.
# ## Call 416 found.
# ## Call 419 found.
# ## Call 425 found.
# ## Call 427 found.
# ## Call 428 found.
# ## Call 431 found.
# ## Call 432 found.
# ## Call 436 found.
# ## Call 441 found.
# ## Call 444 found.
# ## Call 445 found.
# ## Call 446 found.
# ## Call 447 found.
# ## Call 456 found.
# ## Call 457 found.
# ## Call 458 found.
# ## Call 459 found.
# ## Call 461 found.
# ## Call 465 found.
# ## Call 467 found.
# ## Call 470 found.
# ## Call 472 found.
# ## Call 473 found.
# ## Call 474 found.
# ## Call 478 found.
# ## Call 495 found.
# ## Call 496 found.
# ## Call 497 found.
# ## Call 499 found.
# ## Call 500 found.
# ## Call 502 found.
# ## Call 503 found.
# ## Call 504 found.
# ## Call 505 found.
# ## Call 506 found.
# ## Call 510 found.
# ## Call 512 found.
# ## Call 514 found.
# ## Call 515 found.
# ## Call 517 found.
# ## Call 518 found.
# ## Call 520 found.
# ## Call 523 found.
# ## Call 526 found.
# ## Call 527 found.
# ## Call 531 found.
# ## Call 532 found.
# ## Call 533 found.
# ## Call 535 found.
# ## Call 537 found.
# ## Call 539 found.
# ## Call 542 found.
# ## Call 546 found.
# ## Call 547 found.
# ## Call 548 found.
# Call 552 success.
# Call 555 success.
# ## Call 556 found.
# ## Call 557 found.
# Call 559 success.
# Call 560 success.
# Call 561 success.
# Call 562 success.
# Call 566 success.
# Call 567 success.
# Call 568 success.
# Call 570 success.
# Call 572 success.
# Call 581 success.
# Call 584 success.
# Call 585 success.
# Call 588 success.
# Call 589 success.
# Call 590 success.
# Call 591 success.
# Call 594 success.
# Call 596 success.
# Call 597 success.
# Call 598 success.
# Call 603 success.
# Call 605 success.
# Call 606 success.
# Call 607 success.
# Call 609 success.
# Call 614 success.
# Call 616 success.
# Call 618 success.
# Call 628 success.
# Call 633 success.
# Call 634 success.
# Call 637 success.
# Call 638 success.
# Call 649 success.
# Call 650 success.
# Call 651 success.
# Call 652 success.
# Call 655 success.
# Call 656 success.
# Call 659 success.
# Call 660 success.
# Call 662 success.
# Call 663 success.
# Call 664 success.
# Call 665 success.
# Call 666 success.
# Call 672 success.
# Call 673 success.
# Call 677 success.
# Call 680 success.
# Call 685 success.
# Call 689 success.
# Call 690 success.
# Call 695 success.
# Call 697 success.
# Call 698 success.
# Call 702 success.
# Call 705 success.
# Call 707 success.
# Call 709 success.
# Call 711 success.
# Call 714 success.
# Call 718 success.
# Call 721 success.
# Call 724 success.
# Call 726 success.
# Call 736 success.
# Call 738 success.
# Call 747 success.
# Call 748 success.
# Call 749 success.
# Call 754 success.
# Call 755 success.
# Call 757 success.
# Call 764 success.
# Call 767 success.
# Call 771 success.
# Call 773 success.
# Call 774 success.
# Call 775 success.
# Call 776 success.
# Call 778 success.
# Call 779 success.
# Call 783 success.
# Call 787 success.
# Call 788 success.
# Call 789 success.
# Call 790 success.
# Call 791 success.
# Call 792 success.
# Call 794 success.
# Call 795 success.
# Call 797 success.
# Call 799 success.
# Call 805 success.
# Call 806 success.
# Call 809 success.
# ## Call 811 found.
# Call 815 success.
# Call 818 success.
# Call 819 success.
# Call 820 success.
# Call 824 success.
# Call 825 success.
# Call 826 success.
# Call 832 success.
# Call 834 success.
# Call 835 success.
# Call 838 success.
# Call 841 success.
# Call 844 success.
# Call 845 success.
# Call 848 success.
# Call 850 success.
# Call 851 success.
# Call 852 success.
# Call 853 success.
# Call 856 success.
# Call 860 success.
# Call 862 success.
# Call 864 success.
# Call 865 success.
# Call 867 success.
# Call 868 success.
# Call 869 success.
# Call 872 success.
# Call 873 success.
# Call 874 success.
# Call 875 success.
# Call 876 success.
# Call 877 success.
# Call 879 success.
# Call 880 success.
# Call 882 success.
# Call 883 success.
# Call 885 success.
# Call 887 success.
# Call 889 success.
# Call 890 success.
# Call 891 success.
# Call 892 success.
# Call 893 success.
# Call 894 success.
# Call 895 success.
# Call 897 success.
# Call 899 success.
# Call 900 success.
# Call 901 success.
# Call 902 success.
# Call 903 success.
# Call 910 success.
# Call 911 success.
# Call 912 success.
# Call 913 success.
# Call 914 success.
# Call 915 success.
# Call 916 success.
# Call 920 success.
# Call 922 success.
# Call 924 success.
# Call 929 success.
# Call 930 success.
# Call 932 success.
# Call 933 success.
# Call 934 success.
# ##### Call 935 failed: 2. DOI: https://doi.org/10.2225/vol16-issue5-fulltext-11.
# Call 940 success.
# Call 944 success.
# Call 946 success.
# Call 949 success.
# Call 952 success.
# Call 954 success.
# Call 955 success.
# Call 956 success.
# Call 957 success.
# Call 959 success.
# Call 962 success.
# Call 963 success.
# Call 965 success.
# Call 966 success.
# Call 974 success.
# Call 975 success.
# Call 976 success.
# Call 977 success.
# Call 982 success.
# Call 987 success.
# Call 989 success.
# Call 990 success.
# Call 991 success.
# Call 993 success.
# Call 994 success.
# Call 995 success.
# Call 996 success.
# Call 997 success.
# Call 998 success.
# Call 999 success.
# Call 1000 success.
# Call 1014 success.
# Call 1015 success.
# Call 1016 success.
# Call 1018 success.
# Call 1021 success.
# Call 1022 success.
# Call 1023 success.
# Call 1024 success.
# Call 1025 success.
# Call 1030 success.
# Call 1036 success.
# Call 1037 success.
# Call 1038 success.
# Call 1039 success.
# Call 1040 success.
# Call 1041 success.
# Call 1044 success.
# Call 1045 success.
# Call 1046 success.
# Call 1048 success.
# Call 1050 success.
# Call 1051 success.
# Call 1052 success.
# Call 1056 success.
# Call 1059 success.
# Call 1060 success.
# Call 1064 success.
# Call 1065 success.
# Call 1066 success.
# Call 1068 success.
# Call 1071 success.
# Call 1072 success.
# Call 1073 success.
# Call 1074 success.
# Call 1075 success.
# Call 1077 success.
# Call 1078 success.
# Call 1079 success.
# Call 1080 success.
# Call 1085 success.
# Call 1088 success.
# Call 1089 success.
# Call 1090 success.
# Call 1092 success.
# Call 1093 success.
# Call 1094 success.
# Call 1096 success.
# Call 1097 success.
# Call 1098 success.
# Call 1099 success.
# Call 1100 success.
# Call 1102 success.
# Call 1103 success.
# Call 1104 success.
# Call 1106 success.
# Call 1110 success.
# Call 1112 success.
# Call 1114 success.
# Call 1118 success.
# Call 1119 success.
# Call 1121 success.
# Call 1122 success.
# Call 1123 success.
# Call 1125 success.
# Call 1126 success.
# Call 1130 success.
# Call 1137 success.
# Call 1142 success.
# Call 1143 success.
# Call 1149 success.
# Call 1152 success.
# Call 1160 success.
# Call 1161 success.
# Call 1162 success.
# Call 1167 success.
# Call 1170 success.
# Call 1171 success.
# Call 1172 success.
# Call 1173 success.
# Call 1175 success.
# Call 1176 success.
# Call 1178 success.
# Call 1180 success.
# Call 1181 success.
# Call 1182 success.
# Call 1183 success.
# Call 1189 success.
# ## Call 1190 found.
# Call 1192 success.
# Call 1194 success.
# Call 1198 success.
# Call 1200 success.
# Call 1201 success.
# Call 1203 success.
# Call 1209 success.
# Call 1210 success.
# Call 1213 success.
# Call 1214 success.
# Call 1215 success.
# Call 1217 success.
# Call 1222 success.
# Call 1233 success.
# Call 1236 success.
# Call 1238 success.
# Call 1239 success.
# ## Call 1240 found.
# Call 1241 success.
# Call 1242 success.
# Call 1243 success.
# Call 1246 success.
# Call 1247 success.
# Call 1248 success.
# Call 1250 success.
# Call 1254 success.
# Call 1255 success.
# Call 1259 success.
# Call 1264 success.
# Call 1266 success.
# Call 1267 success.
# Call 1268 success.
# Call 1269 success.
# Call 1270 success.
# Call 1271 success.
# Call 1272 success.
# Call 1276 success.
# Call 1278 success.
# Call 1279 success.
# Call 1280 success.
# Call 1282 success.
# Call 1283 success.
# Call 1284 success.
# Call 1287 success.
# Call 1288 success.
# Call 1293 success.
# Call 1294 success.
# Call 1296 success.
# Call 1298 success.
# Call 1299 success.
# Call 1306 success.
# Call 1308 success.
# Call 1309 success.
# Call 1314 success.
# Call 1316 success.
# Call 1317 success.
# Call 1319 success.
# Call 1321 success.
# Call 1322 success.
# Call 1328 success.
# Call 1332 success.
# Call 1333 success.
# Call 1334 success.
# Call 1341 success.
# Call 1342 success.
# Call 1345 success.
# Call 1348 success.
# Call 1349 success.
# Call 1351 success.
# Call 1355 success.
# Call 1356 success.
# Call 1358 success.
# Call 1359 success.
# Call 1360 success.
# Call 1362 success.
# Call 1365 success.
# Call 1369 success.
# Call 1370 success.
# Call 1371 success.
# Call 1374 success.
# Call 1376 success.
# Call 1378 success.
# Call 1381 success.
# Call 1382 success.
# Call 1383 success.
# Call 1388 success.
# Call 1390 success.
# Call 1391 success.
# Call 1393 success.
# Call 1396 success.
# Call 1404 success.
# Call 1406 success.
# Call 1408 success.
# Call 1409 success.
# Call 1410 success.
# Call 1411 success.
# Call 1412 success.
# Call 1414 success.
# Call 1416 success.
# Call 1418 success.
# Call 1424 success.
# Call 1425 success.
# Call 1428 success.
# Call 1431 success.
# Call 1432 success.
# Call 1433 success.
# Call 1434 success.
# Call 1438 success.
# Call 1439 success.
# Call 1444 success.
# Call 1448 success.
# Call 1449 success.
# Call 1451 success.
# Call 1455 success.
# Call 1457 success.
# Call 1458 success.
# Call 1459 success.
# Call 1462 success.
# Call 1463 success.
# Call 1465 success.
# Call 1468 success.
# Call 1471 success.
# Call 1472 success.
# Call 1476 success.
# Call 1482 success.
# Call 1488 success.
# Call 1489 success.
# Call 1492 success.
# Call 1496 success.
# Call 1497 success.
# Call 1499 success.
# Call 1503 success.
# Call 1504 success.
# ## Call 1505 found.
# Call 1506 success.
# Call 1507 success.
# Call 1509 success.
# Call 1515 success.
# Call 1517 success.
# Call 1521 success.
# Call 1526 success.
# Call 1529 success.
# Call 1530 success.
# Call 1531 success.
# Call 1532 success.
# Call 1533 success.
# Call 1537 success.
# Call 1538 success.
# Call 1539 success.
# Call 1542 success.
# Call 1546 success.
# Call 1550 success.
# Call 1551 success.
# Call 1555 success.
# Call 1556 success.
# Call 1558 success.
# Call 1565 success.
# Call 1566 success.
# Call 1567 success.
# Call 1577 success.
# Call 1581 success.
# Call 1582 success.
# Call 1586 success.
# Call 1589 success.
# Call 1593 success.
# Call 1594 success.
# Call 1596 success.
# Call 1599 success.
# Call 1600 success.
# Call 1601 success.
# Call 1604 success.
# Call 1606 success.
# Call 1607 success.
# Call 1608 success.
# Call 1609 success.
# Call 1613 success.
# Call 1614 success.
# Call 1615 success.
# Call 1616 success.
# Call 1617 success.
# Call 1620 success.
# Call 1621 success.
# Call 1622 success.
# Call 1623 success.
# Call 1625 success.
# Call 1627 success.
# Call 1628 success.
# Call 1630 success.
# Call 1631 success.
# Call 1633 success.
# Call 1634 success.
# Call 1639 success.
# Call 1642 success.
# Call 1643 success.
# Call 1644 success.
# Call 1646 success.
# Call 1647 success.
# Call 1648 success.
# Call 1649 success.
# Call 1650 success.
# Call 1651 success.
# Call 1652 success.
# Call 1653 success.
# Call 1654 success.
# Call 1657 success.
# Call 1658 success.
# Call 1660 success.
# Call 1664 success.
# Call 1665 success.
# Call 1668 success.
# Call 1671 success.
# Call 1675 success.
# Call 1682 success.
# Call 1684 success.
# Call 1685 success.
# Call 1686 success.
# Call 1700 success.
# Call 1701 success.
# Call 1702 success.
# Call 1707 success.
# Call 1708 success.
# Call 1709 success.
# Call 1710 success.
# Call 1722 success.
# Call 1723 success.
# Call 1724 success.
# Call 1726 success.
# Call 1727 success.
# Call 1729 success.
# Call 1733 success.
# Call 1735 success.
# Call 1736 success.
# Call 1744 success.
# Call 1750 success.
# Call 1752 success.
# Call 1753 success.
# Call 1754 success.
# Call 1755 success.
# Call 1762 success.
# Call 1768 success.
# Call 1771 success.
# Call 1772 success.
# Call 1773 success.
# Call 1777 success.
# Call 1779 success.
# Call 1781 success.
# Call 1785 success.
# Call 1786 success.
# Call 1788 success.
# Call 1799 success.
# Call 1801 success.
# Call 1804 success.
# Call 1805 success.
# Call 1812 success.
# Call 1813 success.
# Call 1814 success.
# Call 1815 success.
# Call 1819 success.
# Call 1821 success.
# Call 1825 success.
# Call 1826 success.
# Call 1831 success.
# Call 1837 success.
# Call 1838 success.
# Call 1839 success.
# Call 1842 success.
# Call 1848 success.
# Call 1850 success.
# Call 1852 success.
# Call 1853 success.
# ## Call 1854 found.
# Call 1855 success.
# Call 1856 success.
# Call 1858 success.
# Call 1859 success.
# Call 1862 success.
# Call 1865 success.
# Call 1866 success.
# Call 1869 success.
# Call 1870 success.
# Call 1875 success.
# Call 1876 success.
# Call 1878 success.
# Call 1883 success.
# Call 1884 success.
# Call 1886 success.
# Call 1888 success.
# Call 1890 success.
# Call 1893 success.
# Call 1903 success.
# Call 1907 success.
# Call 1908 success.
# Call 1909 success.
# Call 1914 success.
# Call 1915 success.
# Call 1917 success.
# Call 1919 success.
# Call 1924 success.
# Call 1925 success.
# Call 1927 success.
# Call 1929 success.
# Call 1937 success.
# Call 1946 success.
# Call 1955 success.
# Call 1957 success.
# Call 1959 success.
# Call 1962 success.
# Call 1965 success.
# Call 1966 success.
# Call 1971 success.
# Call 1975 success.
# Call 1978 success.
# Call 1980 success.
# Call 1981 success.
# Call 1982 success.
# Call 1984 success.
# Call 1985 success.
# Call 1991 success.
# Call 1996 success.
# Call 1997 success.
# Call 2010 success.
# Call 2013 success.
# Call 2014 success.
# Call 2015 success.
# Call 2018 success.
# Call 2023 success.
# Call 2024 success.
# Call 2026 success.
# Call 2029 success.
# Call 2034 success.
# Call 2037 success.
# Call 2038 success.
# Call 2040 success.
# Call 2044 success.
# Call 2048 success.
# Call 2050 success.
# Call 2051 success.
# Call 2052 success.
# Call 2053 success.
# Call 2058 success.
# Call 2060 success.
# Call 2061 success.
# Call 2062 success.
# Call 2063 success.
# Call 2064 success.
# Call 2068 success.
# Call 2069 success.
# Call 2070 success.
# Call 2073 success.
# Call 2074 success.
# Call 2075 success.
# Call 2076 success.
# Call 2077 success.
# Call 2079 success.
# Call 2083 success.
# Call 2091 success.
# Call 2105 success.
# Call 2106 success.
# Call 2107 success.
# Call 2110 success.
# Call 2114 success.
# Call 2117 success.
# Call 2121 success.
# Call 2122 success.
# Call 2126 success.
# Call 2130 success.
# Call 2133 success.
# Call 2135 success.
# Call 2140 success.
# Call 2141 success.
# Call 2144 success.
# Call 2147 success.
# Call 2150 success.
# Call 2151 success.
# Call 2157 success.
# Call 2158 success.
# Call 2163 success.
# Call 2164 success.
# Call 2165 success.
# Call 2168 success.
# Call 2169 success.
# Call 2170 success.
# Call 2186 success.
# Call 2187 success.
# Call 2189 success.
# Call 2195 success.
# Call 2196 success.
# Call 2197 success.
# Call 2199 success.
# Call 2201 success.
# ##### Call 2204 failed: 3. DOI: https://doi.org/10.1016/s0885-5765(02)90413-3.
# Call 2205 success.
# Call 2208 success.
# Call 2211 success.
# Call 2212 success.
# Call 2217 success.
# Call 2218 success.
# Call 2219 success.
# Call 2220 success.
# Call 2223 success.
# Call 2227 success.
# Call 2231 success.
# Call 2235 success.
# Call 2236 success.
# Call 2241 success.
# Call 2248 success.
# Call 2249 success.
# ## Call 2251 found.
# Call 2252 success.
# Call 2258 success.
# Call 2259 success.
# Call 2268 success.
# Call 2269 success.
# Call 2270 success.
# Call 2271 success.
# Call 2275 success.
# Call 2277 success.
# Call 2278 success.
# Call 2280 success.
# Call 2281 success.
# Call 2282 success.
# Call 2283 success.
# Call 2285 success.
# Call 2286 success.
# Call 2293 success.
# Call 2302 success.
# Call 2305 success.
# Call 2306 success.
# Call 2309 success.
# Call 2311 success.
# Call 2312 success.
# Call 2322 success.
# Call 2324 success.
# Call 2327 success.
# Call 2330 success.
# Call 2332 success.
# Call 2334 success.
# Call 2335 success.
# Call 2336 success.
# Call 2339 success.
# Call 2342 success.
# Call 2343 success.
# Call 2349 success.
# Call 2351 success.
# Call 2353 success.
# Call 2354 success.
# Call 2355 success.
# Call 2359 success.
# Call 2360 success.
# Call 2364 success.
# Call 2366 success.
# Call 2376 success.
# Call 2377 success.
# Call 2378 success.
# Call 2379 success.
# Call 2387 success.
# Call 2390 success.
# Call 2391 success.
# Call 2392 success.
# Call 2394 success.
# Call 2397 success.
# Call 2400 success.
# Call 2404 success.
# Call 2405 success.
# Call 2407 success.
# Call 2409 success.
# Call 2413 success.
# Call 2414 success.
# Call 2415 success.
# Call 2418 success.
# Call 2422 success.
# Call 2423 success.
# Call 2425 success.
# Call 2426 success.
# Call 2428 success.
# Call 2430 success.
# Call 2431 success.
# Call 2432 success.
# Call 2438 success.
# Call 2451 success.
# Call 2456 success.
# Call 2459 success.
# Call 2462 success.
# Call 2464 success.
# Call 2467 success.
# Call 2469 success.
# Call 2470 success.
# Call 2473 success.
# Call 2474 success.
# Call 2477 success.
# Call 2479 success.
# Call 2480 success.
# Call 2482 success.
# Call 2485 success.
# Call 2486 success.
# Call 2487 success.
# Call 2489 success.
# Call 2490 success.
# Call 2491 success.
# Call 2492 success.
# Call 2497 success.
# Call 2498 success.
# Call 2502 success.
# Call 2504 success.
# Call 2505 success.
# Call 2506 success.
# Call 2515 success.
# Call 2525 success.
# Call 2529 success.
# Call 2530 success.
# Call 2531 success.
# Call 2532 success.
# Call 2534 success.
# Call 2535 success.
# Call 2539 success.
# Call 2546 success.
# Call 2547 success.
# Call 2550 success.
# Call 2551 success.
# Call 2553 success.
# Call 2554 success.
# Call 2555 success.
# Call 2558 success.
# Call 2561 success.
# Call 2562 success.
# Call 2563 success.
# Call 2564 success.
# Call 2565 success.
# Call 2566 success.
# Call 2567 success.
# Call 2568 success.
# Call 2572 success.
# Call 2575 success.
# Call 2576 success.
# Call 2577 success.
# Call 2578 success.
# Call 2580 success.
# Call 2581 success.
# Call 2582 success.
# Call 2584 success.
# Call 2589 success.
# Call 2593 success.
# Call 2594 success.
# Call 2595 success.
# Call 2596 success.
# Call 2597 success.
# Call 2598 success.
# Call 2605 success.
# Call 2608 success.
# Call 2611 success.
# Call 2616 success.
# Call 2617 success.
# Call 2619 success.
# Call 2620 success.
# Call 2621 success.
# Call 2622 success.
# Call 2625 success.
# Call 2629 success.
# Call 2631 success.
# Call 2634 success.
# Call 2635 success.
# Call 2640 success.
# Call 2645 success.
# Call 2662 success.
# Call 2664 success.
# Call 2665 success.
# Call 2672 success.
# ##### Call 2673 failed: 4. DOI: https://doi.org/10.1016/0922-338x(90)90239-s.
# Call 2674 success.
# Call 2675 success.
# Call 2676 success.
# Call 2679 success.
# Call 2680 success.
# ##### Call 2683 failed: 5. DOI: https://doi.org/10.1016/0305-0491(93)90349-a.
# Call 2684 success.
# ##### Call 2686 failed: 6. DOI: https://doi.org/10.1016/j.plantsci.2005.08.014.
# Call 2689 success.
# ##### Call 2690 failed: 7. DOI: https://doi.org/10.1016/0076-6879(63)06200-5.
# Call 2692 success.
# Call 2694 success.
# Call 2700 success.
# Call 2701 success.
# Call 2705 success.
# Call 2706 success.
# Call 2707 success.
# Call 2708 success.
# Call 2710 success.
# Call 2711 success.
# Call 2712 success.
# Call 2713 success.
# Call 2714 success.
# Call 2715 success.
# Call 2716 success.
# Call 2717 success.
# Call 2719 success.
# Call 2720 success.
# Call 2721 success.
# Call 2722 success.
# Call 2723 success.
# Call 2724 success.
# Call 2726 success.
# Call 2727 success.
# Call 2728 success.
# Call 2729 success.
# Call 2730 success.
# Call 2731 success.
# Call 2732 success.
# Call 2733 success.
# Call 2737 success.
# Call 2738 success.
# Call 2740 success.
# Call 2742 success.
# Call 2743 success.
# Call 2744 success.
# Call 2747 success.
# Call 2750 success.
# Call 2756 success.
# Call 2757 success.
# Call 2758 success.
# Call 2760 success.
# Call 2769 success.
# Call 2770 success.
# Call 2771 success.
# Call 2772 success.
# Call 2776 success.
# Call 2777 success.
# Call 2779 success.
# Call 2780 success.
# ## Call 2781 found.
# Call 2783 success.
# Call 2784 success.
# Call 2785 success.
# Call 2786 success.
# Call 2787 success.
# Call 2791 success.
# Call 2797 success.
# Call 2800 success.
# Call 2808 success.
# Call 2815 success.
# Call 2817 success.
# Call 2824 success.
# Call 2825 success.
# Call 2827 success.
# Call 2830 success.
# Call 2831 success.
# Call 2832 success.
# Call 2833 success.
# Call 2836 success.
# Call 2837 success.
# Call 2838 success.

# %%
query_out['659773']['doi']
# Out:
# '10.1021/jo00059a013'
